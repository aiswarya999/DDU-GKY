# %% [markdown]
# ## Creating DataFrames

# %%
import pandas as pd

# %% [markdown]
# ### From Dictionary

# %%
dict1 = {'Age':[10,20,15], 'Name':['Vinu', 'Anu', 'Dinu']}

# %%
df1 = pd.DataFrame(dict1)

# %%
df1
# Out:
#    Age  Name
# 0   10  Vinu
# 1   20   Anu
# 2   15  Dinu

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     3 non-null      int64
#  1   Name    3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %% [markdown]
# ## Data Frame using Lists:

# %%
names = ["Manu", "Binu", "Vinu"]
age = [27,26,25]

# %%
df2 = pd.DataFrame(list(zip(names,age)), columns=['Names','Age'])
df2
# Out:
#   Names  Age
# 0  Manu   27
# 1  Binu   26
# 2  Vinu   25

# %%
names = ["Manu", "Binu", "Vinu"]
age = [27,26,25]

# %%
df2 = pd.DataFrame(list(zip(names,age)))
df2
# Out:
#       0   1
# 0  Manu  27
# 1  Binu  26
# 2  Vinu  25

# %% [markdown]
# ## DataFrame from Lists of Dictionaries

# %%
lst = [{'Name':'Aiswarya', 'Age':23, 'Gender':'Female', 'Qualification':'Msc Statistics','Place':'Ernakulam'},
      {'Name':'Reshma AC', 'Age':25, 'Gender':'Female', 'Qualification':'Msc Maths','Place':'Trissur'},
       {'Name':'Aswathi M v', 'Age':23, 'Gender':'Female', 'Qualification':'BTech','Place':'Kannur'},
       {'Name':'Reshma Regunath', 'Age':22, 'Gender':'Female', 'Qualification':'BCA','Place':'Pattanamthitta'},
       {'Name':'Reshmi R Nair', 'Age':31, 'Gender':'Female', 'Qualification':'MBA','Place':'Pattanamthitta'},
       {'Name':'Doniya', 'Age':22, 'Gender':'Female', 'Qualification':'BTech','Place':'Idukki'},
       {'Name':'Sreelekshmi', 'Age':28, 'Gender':'Female', 'Qualification':'MCA','Place':'Pattanamthitta'},
       {'Name':'Veena', 'Age':26, 'Gender':'Female', 'Qualification':'Bsc Maths','Place':'Kozhikode'},
       {'Name':'Parvathy', 'Age':24, 'Gender':'Female', 'Qualification':'BTech','Place':'Kollam'},
       {'Name':'Reneesh', 'Age':27, 'Gender':'Male', 'Qualification':'Bsc Cs','Place':'India'},
       {'Name':'Viswanth V', 'Age':26, 'Gender':'Male', 'Qualification':'BTech','Place':'Adoor'},
       {'Name':'Adarsh Balan', 'Age':24, 'Gender':'Male', 'Qualification':'Btech','Place':'Kayamkulam'},
       {'Name':'Farseen', 'Age':22, 'Gender':'Male', 'Qualification':'B.com','Place':'Malappuram'},
       {'Name':'Suraj', 'Age':32, 'Gender':'Male', 'Qualification':'B.com','Place':'Kottarakara'},
       {'Name':'Geo', 'Age':26, 'Gender':'Male', 'Qualification':'Bsc','Place':'Ernakulam'},
       {'Name':'Anantha Krishnan', 'Age':24, 'Gender':'Male', 'Qualification':'Btech','Place':'Kollam'},
       {'Name':'Sirajudheen', 'Age':26, 'Gender':'Male', 'Qualification':'M.com','Place':'Malappuram'},
       {'Name':'Vaisakh', 'Age':23, 'Gender':'Male', 'Qualification':'BBA','Place':'Malappuram'},
       {'Name':'Biben', 'Age':25, 'Gender':'Male', 'Qualification':'BTech','Place':'Kollam'},
       {'Name':'Arun', 'Age':25, 'Gender':'Male', 'Qualification':'MBA','Place':'Alappuzha'},
       {'Name':'Shaijal', 'Age':21, 'Gender':'Male', 'Qualification':'BCA','Place':'Malappuram'},
       {'Name':'Christy', 'Age':21, 'Gender':'Male', 'Qualification':'BE Cse','Place':'Wayanad'},
       {'Name':'Rinto', 'Age':25, 'Gender':'Male', 'Qualification':'BTech','Place':'Palakkad'},
       {'Name':'Joyal Joseph', 'Age':25, 'Gender':'Male', 'Qualification':'Bsc Mathematics','Place':'Pala'},
       {'Name':'Saneesh', 'Age':32, 'Gender':'Male', 'Qualification':'BE Cs','Place':'Kasargod'},
      ]

# %%
df = pd.DataFrame(lst)
df
# Out:
#                 Name  Age  Gender    Qualification           Place
# 0           Aiswarya   23  Female   Msc Statistics       Ernakulam
# 1          Reshma AC   25  Female        Msc Maths         Trissur
# 2        Aswathi M v   23  Female            BTech          Kannur
# 3    Reshma Regunath   22  Female              BCA  Pattanamthitta
# 4      Reshmi R Nair   31  Female              MBA  Pattanamthitta
# 5             Doniya   22  Female            BTech          Idukki
# 6        Sreelekshmi   28  Female              MCA  Pattanamthitta
# 7              Veena   26  Female        Bsc Maths       Kozhikode
# 8           Parvathy   24  Female            BTech          Kollam
# 9            Reneesh   27    Male           Bsc Cs           India
# 10        Viswanth V   26    Male            BTech           Adoor
# 11      Adarsh Balan   24    Male            Btech      Kayamkulam
# 12           Farseen   22    Male            B.com      Malappuram
# ...

# %% [markdown]
# ### DataFrame using Lists:

# %%
names = ["Aiswarya","Reshma AC","Aswathi M v","Reshma Regunath","Reshmi R Nair","Doniya","Sreelekshmi","Veena","Parvathy","Reneesh","Viswanth V","Adarsh Balan","Farseen","Suraj","Geo","Anantha Krishnan","Sirajudheen","Vaisakh","Biben","Arun","Shaijal","Christy","Rinto","Joyal Joseph","Saneesh"]
age = [23,25,23,22,31,22,28,26,24,27,26,24,22,32,26,24,26,23,25,21,21,25,25,25,32]
gender = ["Female","Female","Female","Female","Female","Female","Female","Female","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male"]
qualification = ["Msc Statistics","Msc Maths","BTech","BCA","MBA","BTech","MCA","Bsc Maths","BTech","Bsc Cs","BTech","Btech","B.com","B.com","Bsc","Btech","M.com","BBA","BTech","MBA","BCA","BE Cse","BTech","Bsc Mathematics","BE Cs"]
place = ["Ernakulam","Trissur","Kannur","Pattanamthitta","Pattanamthitta","Idukki","Pattanamthitta","Kozhikode","Kollam","India","Adoor","Kayamkulam","Malappuram","Kottarakara","Ernakulam","Kollam","Malappuram","Malappuram","Kollam","Alappuzha","Malappuram","Wayanad","Palakkad","Pala","Kasargod"]

# %%
df2 = pd.DataFrame(list(zip(names, age, gender,qualification,place)), columns=['Name','Age','Gender','Qualification','Place'])
df2
# Out:
#                 Name  Age  Gender    Qualification           Place
# 0           Aiswarya   23  Female   Msc Statistics       Ernakulam
# 1          Reshma AC   25  Female        Msc Maths         Trissur
# 2        Aswathi M v   23  Female            BTech          Kannur
# 3    Reshma Regunath   22  Female              BCA  Pattanamthitta
# 4      Reshmi R Nair   31  Female              MBA  Pattanamthitta
# 5             Doniya   22  Female            BTech          Idukki
# 6        Sreelekshmi   28  Female              MCA  Pattanamthitta
# 7              Veena   26  Female        Bsc Maths       Kozhikode
# 8           Parvathy   24  Female            BTech          Kollam
# 9            Reneesh   27    Male           Bsc Cs           India
# 10        Viswanth V   26    Male            BTech           Adoor
# 11      Adarsh Balan   24    Male            Btech      Kayamkulam
# 12           Farseen   22    Male            B.com      Malappuram
# ...

# %% [markdown]
# ### From Dictionary

# %%
dict2 = {'Name':["Aiswarya","Reshma AC","Aswathi M v","Reshma Regunath","Reshmi R Nair","Doniya","Sreelekshmi","Veena","Parvathy","Reneesh","Viswanth V","Adarsh Balan","Farseen","Suraj","Geo","Anantha Krishnan","Sirajudheen","Vaisakh","Biben","Arun","Shaijal","Christy","Rinto","Joyal Joseph","Saneesh"], 'Age':[23,25,23,22,31,22,28,26,24,27,26,24,22,32,26,24,26,23,25,21,21,25,25,25,32], 'Gender':["Female","Female","Female","Female","Female","Female","Female","Female","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male"
], 'Qualification':["Msc Statistics","Msc Maths","BTech","BCA","MBA","BTech","MCA","Bsc Maths","BTech","Bsc Cs","BTech","Btech","B.com","B.com","Bsc","Btech","M.com","BBA","BTech","MBA","BCA","BE Cse","BTech","Bsc Mathematics","BE Cs"]
, 'Place':["Ernakulam","Trissur","Kannur","Pattanamthitta","Pattanamthitta","Idukki","Pattanamthitta","Kozhikode","Kollam","India","Adoor","Kayamkulam","Malappuram","Kottarakara","Ernakulam","Kollam","Malappuram","Malappuram","Kollam","Alappuzha","Malappuram","Wayanad","Palakkad","Pala","Kasargod"]}

# %%
df3 = pd.DataFrame(dict2)
df3
# Out:
#                 Name  Age  Gender    Qualification           Place
# 0           Aiswarya   23  Female   Msc Statistics       Ernakulam
# 1          Reshma AC   25  Female        Msc Maths         Trissur
# 2        Aswathi M v   23  Female            BTech          Kannur
# 3    Reshma Regunath   22  Female              BCA  Pattanamthitta
# 4      Reshmi R Nair   31  Female              MBA  Pattanamthitta
# 5             Doniya   22  Female            BTech          Idukki
# 6        Sreelekshmi   28  Female              MCA  Pattanamthitta
# 7              Veena   26  Female        Bsc Maths       Kozhikode
# 8           Parvathy   24  Female            BTech          Kollam
# 9            Reneesh   27    Male           Bsc Cs           India
# 10        Viswanth V   26    Male            BTech           Adoor
# 11      Adarsh Balan   24    Male            Btech      Kayamkulam
# 12           Farseen   22    Male            B.com      Malappuram
# ...
