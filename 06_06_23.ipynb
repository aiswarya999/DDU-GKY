# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./athlete_events.csv')
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
data.sample()
# Out:
#           ID          Name Sex   Age  Height  Weight         Team  NOC  \
# 56520  28956  Shane Dobbin   M  30.0   183.0    72.0  New Zealand  NZL
#
#              Games  Year  Season       City          Sport  \
# 56520  2010 Winter  2010  Winter  Vancouver  Speed Skating
#
#                                   Event Medal
# 56520  Speed Skating Men's 5,000 metres   NaN

# %%
data.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
data.describe().T
# Out:
#            count          mean           std     min      25%      50%  \
# ID      271116.0  68248.954396  39022.286345     1.0  34643.0  68205.0
# Age     261642.0     25.556898      6.393561    10.0     21.0     24.0
# Height  210945.0    175.338970     10.518462   127.0    168.0    175.0
# Weight  208241.0     70.702393     14.348020    25.0     60.0     70.0
# Year    271116.0   1978.378480     29.877632  1896.0   1960.0   1988.0
#
#               75%       max
# ID      102097.25  135571.0
# Age         28.00      97.0
# Height     183.00     226.0
# Weight      79.00     214.0
# Year      2002.00    2016.0

# %%
season_year_sum=data.groupby(['Season'])['Year'].sum()
season_year_sum
# Out:
# Season
# Summer    439833322
# Winter     96536738
# Name: Year, dtype: int64

# %%
season_year_sum=data.groupby(['Season'])['Year'].mean()*100
season_year_sum
# Out:
# Season
# Summer    197631.709443
# Winter    198782.509678
# Name: Year, dtype: float64

# %%
data.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %% [markdown]
# ## QUESTIONS

# %% [markdown]
# #### Find which country has the highest number of appearances in the data set?

# %%
data.Team.value_counts()
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
#                  ...
# Briar                1
# Hannover             1
# Nan-2                1
# Brentina             1
# Digby                1
# Name: Team, Length: 1184, dtype: int64

# %% [markdown]
# #### filter and the dataset based on seasons and make separate datasets

# %%
summer = data[data['Season'] == 'Summer']
summer
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 271106  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
summer = data[data['Season'] == 'Winter']
summer
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5  Christine Jacoba Aaftink   F  27.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# 4       Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...

# %% [markdown]
# #### find the genderwise count of players?

# %%
data.Sex.value_counts()
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %% [markdown]
# ## QUESTIONS
#
# ### Which country has won the most number of medals
# ### Countries with no gold medal at all
# ### Progressive report of medals by countries
# ### Athlete with most height
# ### Youngest player
# ### Countries without any female players
# ### Gold medalist in basketball event, 1992 summer olympics
# ### Age category wise medal count
# ### Oldest person who won gold medal
# ### Year in which most number of events
# ### Year wise count of participant countries
# ### count of winter and summer olympics
# ### Sport in which there is less events
# ### Most occuring event
# ### USA's - Yearly medal count
# ### Country with more medals and less number of players
# ### City with most number of olymipcs held
# ### Which are the newly added sports
# ### Second most country won bronze medal

# %% [markdown]
# ### Display all columns

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# ### Feature engineering the medal column

# %%
data.Medal.unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %% [markdown]
# ### Lets create seoarate columns using if_else statement for number of medals

# %%
data['Gold']=[1 if medal == 'Gold' else 0 for medal in data['Medal']]

# %%
data['Silver']=[1 if medal == 'Silver' else 0 for medal in data['Medal']]
data['Bronze']=[1 if medal == 'Bronze' else 0 for medal in data['Medal']]

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal  Gold  Silver  Bronze
# 0       Basketball Men's Basketball   NaN     0       0       0
# ...

# %%
data.drop(columns=['ID','Games'], inplace=True)

# %%
data.head()
# Out:
#                        Name Sex   Age  Height  Weight            Team  NOC  \
# 0                 A Dijiang   M  24.0   180.0    80.0           China  CHN
# 1                  A Lamusi   M  23.0   170.0    60.0           China  CHN
# 2       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 3      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 4  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
#
#    Year  Season       City          Sport                             Event  \
# 0  1992  Summer  Barcelona     Basketball       Basketball Men's Basketball
# 1  2012  Summer     London           Judo      Judo Men's Extra-Lightweight
# 2  1920  Summer  Antwerpen       Football           Football Men's Football
# 3  1900  Summer      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War
# 4  1988  Winter    Calgary  Speed Skating  Speed Skating Women's 500 metres
#
#   Medal  Gold  Silver  Bronze
# ...

# %% [markdown]
# ### Which country has won the most number of medals

# %%
country_wise_medal = data.groupby(['Team'])['Gold','Silver','Bronze'].sum()
country_wise_medal
# Out:
#                        Gold  Silver  Bronze
# Team
# 30. Februar               0       0       0
# A North American Team     0       0       4
# Acipactli                 0       0       0
# Acturus                   0       0       0
# Afghanistan               0       0       2
# ...                     ...     ...     ...
# Zambia                    0       1       1
# Zefyros                   0       0       0
# Zimbabwe                 17       4       1
# Zut                       0       3       0
# rn-2                      0       0       0
#
# [1184 rows x 3 columns]

# %% [markdown]
# ### Lets add a new column to the groupby object

# %%
country_wise_medal['Total'] =country_wise_medal['Gold']+country_wise_medal['Silver']+country_wise_medal['Bronze']
country_wise_medal
# Out:
#                        Gold  Silver  Bronze  Total
# Team
# 30. Februar               0       0       0      0
# A North American Team     0       0       4      4
# Acipactli                 0       0       0      0
# Acturus                   0       0       0      0
# Afghanistan               0       0       2      2
# ...                     ...     ...     ...    ...
# Zambia                    0       1       1      2
# Zefyros                   0       0       0      0
# Zimbabwe                 17       4       1     22
# Zut                       0       3       0      3
# rn-2                      0       0       0      0
#
# [1184 rows x 4 columns]

# %%
country_wise_medal.sort_values(by = 'Total', ascending=False)
# Out:
#                Gold  Silver  Bronze  Total
# Team
# United States  2474    1512    1233   5219
# Soviet Union   1058     716     677   2451
# Germany         679     627     678   1984
# Great Britain   519     582     572   1673
# France          455     518     577   1550
# ...             ...     ...     ...    ...
# Ireland-1         0       0       0      0
# Israel-1          0       0       0      0
# Israel-2          0       0       0      0
# Italy-3           0       0       0      0
# rn-2              0       0       0      0
#
# [1184 rows x 4 columns]

# %%
country_wise_medal.nlargest(1,'Total')
# Out:
#                Gold  Silver  Bronze  Total
# Team
# United States  2474    1512    1233   5219

# %%
country_wise_medal.nsmallest(1,'Total')
# Out:
#              Gold  Silver  Bronze  Total
# Team
# 30. Februar     0       0       0      0

# %% [markdown]
# ### Country with no gold medal at all

# %%
No_gold_medals=country_wise_medal[country_wise_medal['Gold']==0]
No_gold_medals
# Out:
#                        Gold  Silver  Bronze  Total
# Team
# 30. Februar               0       0       0      0
# A North American Team     0       0       4      4
# Acipactli                 0       0       0      0
# Acturus                   0       0       0      0
# Afghanistan               0       0       2      2
# ...                     ...     ...     ...    ...
# Yugoslavia-2              0       0       0      0
# Zambia                    0       1       1      2
# Zefyros                   0       0       0      0
# Zut                       0       3       0      3
# rn-2                      0       0       0      0
#
# [942 rows x 4 columns]

# %%
len(No_gold_medals)
# Out:
# 942

# %%
List_No_gold_medals=list(No_gold_medals.index)
List_No_gold_medals
# Out:
# ['30. Februar',
#  'A North American Team',
#  'Acipactli',
#  'Acturus',
#  'Afghanistan',
#  'Akatonbo',
#  'Alain IV',
#  'Albania',
#  'Alcaid',
#  'Alcyon-6',
#  'Alcyon-7',
#  'Aldebaran',
#  'Aldebaran II',
#  'Aletta',
#  'Ali-Baba II',
#  'Ali-Baba IV',
#  'Ali-Baba IX',
#  'Ali-Baba VI',
#  'Allegro',
#  'Almaz',
#  'Aloha II',
#  'American Samoa',
#  'Amolgavar',
#  'Amstel Amsterdam',
#  'Amulet-3',
#  'Amulet-7',
#  'Andorinha',
#  'Andorra',
#  'Andromeda',
#  'Angerburg',
#  'Angola',
#  'Anitra',
#  'Antares',
#  'Antigua and Barbuda',
#  'Antwerpia V',
#  'Apache',
#  'Aphrodite',
#  'Arcturus',
#  'Ardilla',
#  'Aretusa',
#  'Argentina-1',
#  'Argentina-2',
#  'Argeste',
#  'Argo II',
#  'Argonaut Rowing Club',
#  'Argus',
#  'Ariel',
#  'Ariette-10',
#  'Ariette-8',
#  'Aruba',
#  'Astrid III',
#  'Atalanta Boat Club-2',
#  'Athens-2',
#  'Augsburg',
#  'Ausonia',
#  'Australia-2',
#  'Australia-3',
#  'Australia/Great Britain',
#  'Austria-2',
# ...

# %%
print("Number of countries with no Gold medals  :", len(List_No_gold_medals))
# Out:
# Number of countries with no Gold medals  : 942

# %% [markdown]
# ### Is India included in the above list?

# %%
Zero_medals_india = data.query("Gold == 0 & Silver == 0 & Bronze == 0 & NOC == 'IND'")
Zero_medals_india
# Out:
#                                                  Name Sex   Age  Height  \
# 505                                    S. Abdul Hamid   M   NaN     NaN
# 506                                    S. Abdul Hamid   M   NaN     NaN
# 895                   Shiny Kurisingal Abraham-Wilson   F  19.0   167.0
# 896                   Shiny Kurisingal Abraham-Wilson   F  19.0   167.0
# 897                   Shiny Kurisingal Abraham-Wilson   F  23.0   167.0
# ...                                               ...  ..   ...     ...
# 264138                           Mohammad Anas Yahiya   M  21.0   177.0
# 264139                           Mohammad Anas Yahiya   M  21.0   177.0
# 265876  Thyadathuvilla Chandrapillai "T. C." Yohannan   M  29.0   174.0
# 270912                                   Geeta Zutshi   F  23.0   167.0
# 270913                                   Geeta Zutshi   F  27.0   167.0
#
#         Weight   Team  NOC  Year  Season            City      Sport  \
# ...
